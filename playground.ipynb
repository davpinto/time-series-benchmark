# %%
import pandas as pd
import numpy as np
from datetime import datetime
import statsmodels.api as sm

# %%
x = pd.DataFrame({'Min': [3.2, 2.1, 7.4, 5.2, 3.9, 0.7], 
                  'Max': [5.3, 3.7, 11.2, 8.1, 9.2, 3.2], 
                  'Avg': [4.7, 3.0, 8.1, 7.2, 5.1, 1.8]},
                  index=[datetime(2017,8,1), datetime(2017,8,2), 
                  datetime(2017,8,3), datetime(2017,8,4), 
                  datetime(2017,8,5), datetime(2017,8,6)])

# %%
x.plot()

# %%
x.asfreq('12H').fillna(method="pad").plot()

# %%
x.resample('2D').agg(np.mean).plot()

# %%
x.plot()

# %%
sm.graphics.tsa.plot_acf(x.Max)

# %%
sm.graphics.tsa.plot_pacf(x.Max)
